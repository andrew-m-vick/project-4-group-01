# %%
import pandas as pd

# %%
df = pd.read_csv('us-dealers-used.csv')
# Out:
# /var/folders/7b/trlfgd_d5gv_jv53bccbf7rw0000gn/T/ipykernel_41899/4071429681.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('us-dealers-used.csv')

# %%
df.head()
# Out:
#               id                vin    price     miles    stock_no    year  \
# 0  38b2f52e-8f5d  1GCWGFCF3F1284719  20998.0  115879.0  W1T503168C  2015.0
# 1  97ba4955-ccf0  WBY7Z8C59JVB87514  27921.0    7339.0      P33243  2018.0
# 2  be1da9fd-0f34  ML32F4FJ2JHF10325  11055.0   39798.0     WM2091A  2018.0
# 3  84327e45-6cb6  1GCPTEE15K1291189  52997.0   28568.0    9U2Y425A  2019.0
# 4  cde691c3-91dd  1G2AL18F087312093      NaN  188485.0     T36625A  2008.0
#
#          make          model      trim  body_type  ... drivetrain  \
# 0   Chevrolet  Express Cargo  Work Van  Cargo Van  ...        RWD
# 1         BMW             i3         s  Hatchback  ...        RWD
# 2  Mitsubishi      Mirage G4        SE      Sedan  ...        FWD
# 3   Chevrolet       Colorado       ZR2     Pickup  ...        4WD
# 4     Pontiac             G5      Base      Coupe  ...        FWD
#
#   transmission                    fuel_type engine_size  engine_block  \
# 0    Automatic               E85 / Unleaded         4.8             V
# 1    Automatic  Electric / Premium Unleaded         0.6             I
# 2    Automatic                     Unleaded         1.2             I
# 3    Automatic                       Diesel         2.8             I
# 4    Automatic                     Unleaded         2.2             I
#
#                     seller_name                        street           city  \
# 0          nissan ellicott city  8569 Baltimore National Pike  Ellicott City
# 1  hendrick honda pompano beach        5381 N Federal Highway  Pompano Beach
# 2            russ darrow toyota      2700 West Washington St.      West Bend
# 3                     young kia         308 North Main Street         Layton
# 4                 pappas toyota              10011 Spencer Rd   Saint Peters
#
#   state    zip
# 0    MD  21043
# 1    FL  33064
# 2    WI  53095
# 3    UT  84041
# 4    MO  63376
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7104304 entries, 0 to 7104303
# Data columns (total 21 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   id            object
#  1   vin           object
#  2   price         float64
#  3   miles         float64
#  4   stock_no      object
#  5   year          float64
#  6   make          object
#  7   model         object
#  8   trim          object
#  9   body_type     object
#  10  vehicle_type  object
#  11  drivetrain    object
#  12  transmission  object
#  13  fuel_type     object
#  14  engine_size   float64
#  15  engine_block  object
#  16  seller_name   object
#  17  street        object
#  18  city          object
#  19  state         object
#  20  zip           object
# dtypes: float64(4), object(17)
# memory usage: 1.1+ GB

# %%
pd.set_option('display.max_rows', None)

make_counts = df['make'].value_counts()
make_counts
# Out:
# make
# Ford             933834
# Chevrolet        815351
# Toyota           647263
# Honda            516484
# Nissan           451098
# Jeep             433401
# BMW              270940
# Hyundai          268377
# GMC              256735
# Mercedes-Benz    227486
# Kia              226792
# RAM              211684
# Dodge            205920
# Subaru           190266
# Lexus            179314
# Volkswagen       159730
# Audi             128078
# Mazda            111099
# Cadillac         102680
# Acura             99906
# Buick             92328
# INFINITI          83252
# Chrysler          79927
# Lincoln           66740
# Land Rover        63629
# Volvo             52264
# Porsche           40292
# MINI              37294
# Mitsubishi        32919
# Jaguar            26907
# Alfa Romeo        10488
# Maserati           9641
# GENESIS            8704
# Scion              8022
# Pontiac            8019
# FIAT               7184
# Tesla              7139
# Mercury            4637
# Saturn             4501
# Bentley            4193
# Ferrari            3781
# Hummer             2779
# Suzuki             1976
# Aston Martin       1796
# Rolls-Royce        1645
# smart              1427
# Lamborghini        1423
# Isuzu              1201
# McLaren            1196
# Saab                946
# Oldsmobile          642
# Plymouth            244
# KARMA               160
# Lotus               142
# Am General          121
# Eagle               118
# Geo                  55
# Fisker               52
# Maybach              23
# Bugatti              23
# Sterling             22
# Datsun                7
# Daewoo                3
# Peugeot               2
# Panoz                 1
# AMC                   1
# Name: count, dtype: int64

# %%
df.dropna(inplace=True)

# %%
# Drop specified columns
columns_to_drop = ['id', 'vin', 'stock_no', 'seller_name','street','zip']
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.shape[0]
# Out:
# 6167605

# %%
df_filtered = df[df['year'] >= 2017]

# %%
makes_to_drop = make_counts[make_counts < 10489].index

# %%
df_filtered = df_filtered[~df_filtered['make'].isin(makes_to_drop)]

# %%
df_sampled = df_filtered.sample(n=150000, random_state=42)

# %%
df_sampled.head(25)
# Out:
#            price    miles    year           make                  model  \
# 1432405  26785.0  35941.0  2018.0          Dodge                Durango
# 5010971  28888.0  83382.0  2017.0            GMC                 Acadia
# 5949319  17500.0  50568.0  2017.0           Ford                 Escape
# 7013461  32300.0  48713.0  2018.0            RAM        Ram 1500 Pickup
# 5327492  42817.0  35288.0  2019.0            RAM        Ram 2500 Pickup
# 377362   40477.0  27370.0  2020.0            BMW               5 Series
# 3223300  28500.0  61382.0  2018.0       Chrysler               Pacifica
# 1277563  52250.0  35333.0  2018.0           Ford                  F-150
# 1088994  29991.0   1137.0  2021.0            Kia                Sorento
# 4225275  20988.0   9992.0  2019.0         Nissan                  Kicks
# 5359265  46500.0  15032.0  2020.0            RAM        Ram 2500 Pickup
# 745544   17988.0  24235.0  2018.0         Toyota                Corolla
# 1402740  18996.0  39729.0  2019.0       Chrysler                    300
# 2125385  17999.0  55167.0  2018.0        Hyundai                Elantra
# 2685153  22000.0  33826.0  2018.0           Jeep               Cherokee
# 460105   81999.0   3914.0  2020.0  Mercedes-Benz                    GLE
# 4125157  15869.0  32664.0  2018.0          Honda                    Fit
# 6248860  19963.0   6561.0  2020.0            Kia               Sportage
# 6027213  18926.0  25961.0  2017.0         Toyota            Prius Prime
# 2235046  78999.0  11020.0  2020.0           Audi                     A8
# 6634217  35878.0  20513.0  2018.0         Toyota                 Tacoma
# 7082503  78980.0   8545.0  2020.0            GMC  Sierra 3500 Denali HD
# 3924224  27695.0  25499.0  2018.0            BMW               3 Series
# 1107676  43500.0  25801.0  2019.0           Ford                  F-150
# 1629152  53589.0  20016.0  2019.0      Chevrolet         Silverado 1500
#
#                  trim  body_type vehicle_type drivetrain transmission  \
# 1432405           SXT        SUV        Truck        RWD    Automatic
# 5010971        Denali  Crossover        Truck        4WD    Automatic
# 5949319            SE        SUV        Truck        4WD    Automatic
# 7013461      Big Horn     Pickup        Truck        RWD    Automatic
# 5327492      Big Horn     Pickup        Truck        RWD    Automatic
# 377362           530i      Sedan          Car        4WD    Automatic
# 3223300       Limited    Minivan        Truck        FWD    Automatic
# 1277563      Platinum     Pickup        Truck        4WD    Automatic
# 1088994             S        SUV        Truck        FWD    Automatic
# 4225275            SR        SUV        Truck        FWD    Automatic
# 5359265     Tradesman     Pickup        Truck        4WD    Automatic
# 745544             LE      Sedan          Car        FWD    Automatic
# 1402740       Limited      Sedan          Car        4WD    Automatic
# 2125385           SEL      Sedan          Car        FWD    Automatic
# 2685153       Limited        SUV        Truck        4WD    Automatic
# 460105         GLE580        SUV        Truck        4WD    Automatic
# 4125157         Sport  Hatchback          Car        FWD    Automatic
# 6248860            LX        SUV        Truck        FWD    Automatic
# 6027213       Premium  Hatchback          Car        FWD    Automatic
# 2235046          Base      Sedan          Car        4WD    Automatic
# 6634217  TRD Off Road     Pickup        Truck        4WD    Automatic
# 7082503        Denali     Pickup        Truck        4WD    Automatic
# 3924224          330i      Sedan          Car        4WD    Automatic
# 1107676           XLT     Pickup        Truck        4WD    Automatic
# 1629152           RST     Pickup        Truck        4WD    Automatic
#
#                            fuel_type  engine_size engine_block           city  \
# 1432405                     Unleaded          3.6            V          Miami
# 5010971                     Unleaded          3.6            V         Irving
# 5949319                     Unleaded          1.5            I         Albany
# 7013461                     Unleaded          5.7            V     Chesapeake
# 5327492                     Unleaded          6.4            V       Savannah
# 377362              Premium Unleaded          2.0            I       Marietta
# 3223300                     Unleaded          3.6            V       Rockwall
# 1277563                     Unleaded          3.5            V     Broken Bow
# 1088994                     Unleaded          2.5            I        Houston
# 4225275                     Unleaded          1.6            I         Duluth
# 5359265                     Unleaded          6.4            V       Beeville
# 745544                      Unleaded          1.8            I      Dyersburg
# 1402740                     Unleaded          3.6            V     Fort Myers
# 2125385                     Unleaded          2.0            I         Tucson
# 2685153                     Unleaded          2.4            I       Johnston
# 460105   Electric / Premium Unleaded          4.0            I         Lowell
# 4125157                     Unleaded          1.5            I   Murfreesboro
# 6248860                     Unleaded          2.4            I     Fort Myers
# 6027213          Electric / Unleaded          1.8            I      Getzville
# 2235046             Premium Unleaded          4.0            V  Winston-Salem
# 6634217                     Unleaded          3.5            V      Brunswick
# 7082503                       Diesel          6.6            V     Marshfield
# 3924224             Premium Unleaded          2.0            I  Spring Valley
# 1107676                     Unleaded          2.7            V     Cincinnati
# 1629152                     Unleaded          5.3            V         Dublin
#
#         state
# 1432405    FL
# 5010971    TX
# 5949319    NY
# 7013461    VA
# 5327492    GA
# 377362     GA
# 3223300    TX
# 1277563    OK
# 1088994    TX
# 4225275    GA
# 5359265    TX
# 745544     TN
# 1402740    FL
# 2125385    AZ
# 2685153    RI
# 460105     MI
# 4125157    TN
# 6248860    FL
# 6027213    NY
# 2235046    NC
# 6634217    OH
# 7082503    MO
# 3924224    NY
# 1107676    OH
# 1629152    CA

# %%
df_sampled.to_csv('used_clean.csv', index=False)
