# %%
import pandas as pd

# %%
df = pd.read_csv('us-dealers-used.csv')
# Out:
# /var/folders/7b/trlfgd_d5gv_jv53bccbf7rw0000gn/T/ipykernel_60218/4071429681.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('us-dealers-used.csv')

# %%
df.head()
# Out:
#               id                vin    price     miles    stock_no    year  \
# 0  38b2f52e-8f5d  1GCWGFCF3F1284719  20998.0  115879.0  W1T503168C  2015.0
# 1  97ba4955-ccf0  WBY7Z8C59JVB87514  27921.0    7339.0      P33243  2018.0
# 2  be1da9fd-0f34  ML32F4FJ2JHF10325  11055.0   39798.0     WM2091A  2018.0
# 3  84327e45-6cb6  1GCPTEE15K1291189  52997.0   28568.0    9U2Y425A  2019.0
# 4  cde691c3-91dd  1G2AL18F087312093      NaN  188485.0     T36625A  2008.0
#
#          make          model      trim  body_type  ... drivetrain  \
# 0   Chevrolet  Express Cargo  Work Van  Cargo Van  ...        RWD
# 1         BMW             i3         s  Hatchback  ...        RWD
# 2  Mitsubishi      Mirage G4        SE      Sedan  ...        FWD
# 3   Chevrolet       Colorado       ZR2     Pickup  ...        4WD
# 4     Pontiac             G5      Base      Coupe  ...        FWD
#
#   transmission                    fuel_type engine_size  engine_block  \
# 0    Automatic               E85 / Unleaded         4.8             V
# 1    Automatic  Electric / Premium Unleaded         0.6             I
# 2    Automatic                     Unleaded         1.2             I
# 3    Automatic                       Diesel         2.8             I
# 4    Automatic                     Unleaded         2.2             I
#
#                     seller_name                        street           city  \
# 0          nissan ellicott city  8569 Baltimore National Pike  Ellicott City
# 1  hendrick honda pompano beach        5381 N Federal Highway  Pompano Beach
# 2            russ darrow toyota      2700 West Washington St.      West Bend
# 3                     young kia         308 North Main Street         Layton
# 4                 pappas toyota              10011 Spencer Rd   Saint Peters
#
#   state    zip
# 0    MD  21043
# 1    FL  33064
# 2    WI  53095
# 3    UT  84041
# 4    MO  63376
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7104304 entries, 0 to 7104303
# Data columns (total 21 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   id            object
#  1   vin           object
#  2   price         float64
#  3   miles         float64
#  4   stock_no      object
#  5   year          float64
#  6   make          object
#  7   model         object
#  8   trim          object
#  9   body_type     object
#  10  vehicle_type  object
#  11  drivetrain    object
#  12  transmission  object
#  13  fuel_type     object
#  14  engine_size   float64
#  15  engine_block  object
#  16  seller_name   object
#  17  street        object
#  18  city          object
#  19  state         object
#  20  zip           object
# dtypes: float64(4), object(17)
# memory usage: 1.1+ GB

# %%
pd.set_option('display.max_rows', None)

make_counts = df['make'].value_counts()
make_counts
# Out:
# make
# Ford             933834
# Chevrolet        815351
# Toyota           647263
# Honda            516484
# Nissan           451098
# Jeep             433401
# BMW              270940
# Hyundai          268377
# GMC              256735
# Mercedes-Benz    227486
# Kia              226792
# RAM              211684
# Dodge            205920
# Subaru           190266
# Lexus            179314
# Volkswagen       159730
# Audi             128078
# Mazda            111099
# Cadillac         102680
# Acura             99906
# Buick             92328
# INFINITI          83252
# Chrysler          79927
# Lincoln           66740
# Land Rover        63629
# Volvo             52264
# Porsche           40292
# MINI              37294
# Mitsubishi        32919
# Jaguar            26907
# Alfa Romeo        10488
# Maserati           9641
# GENESIS            8704
# Scion              8022
# Pontiac            8019
# FIAT               7184
# Tesla              7139
# Mercury            4637
# Saturn             4501
# Bentley            4193
# Ferrari            3781
# Hummer             2779
# Suzuki             1976
# Aston Martin       1796
# Rolls-Royce        1645
# smart              1427
# Lamborghini        1423
# Isuzu              1201
# McLaren            1196
# Saab                946
# Oldsmobile          642
# Plymouth            244
# KARMA               160
# Lotus               142
# Am General          121
# Eagle               118
# Geo                  55
# Fisker               52
# Maybach              23
# Bugatti              23
# Sterling             22
# Datsun                7
# Daewoo                3
# Peugeot               2
# Panoz                 1
# AMC                   1
# Name: count, dtype: int64

# %%
df_tesla = df[df['make'].str.lower() == 'tesla'].copy()

# %%
df_tesla['transmission'] = df_tesla['transmission'].fillna('Automatic')
df_tesla['fuel_type'] = df_tesla['fuel_type'].fillna('Electric')
df_tesla['engine_block'] = df_tesla['engine_block'].fillna('E')
df_tesla['engine_size'] = df_tesla['engine_size'].fillna('E')

# %%
df_tesla.dropna(inplace=True)

# %%
# Convert `miles` and `year` columns to integer
df_tesla['miles'] = df_tesla['miles'].astype(int)
df_tesla['year'] = df_tesla['year'].astype(int)

# %%
# Drop specified columns
columns_to_drop = ['id', 'vin', 'stock_no', 'seller_name','street']
df_tesla.drop(columns=columns_to_drop, inplace=True)

# %%
df_tesla_filtered = df_tesla[df_tesla['year'] >= 2017]

# %%
df_tesla_filtered = df_tesla_filtered[df_tesla_filtered['miles'] >= 500]

# %%
# Drop duplicate rows based on the 'vin' column, keeping the first occurrence
df_cleaned = df.drop_duplicates(subset=['vin'], keep='first').copy()

# %%
df_cleaned.dropna(inplace=True)

# %%
# Convert `miles` and `year` columns to integer
df_cleaned['miles'] = df_cleaned['miles'].astype(int)
df_cleaned['year'] = df_cleaned['year'].astype(int)

# %%
# Drop specified columns
columns_to_drop = ['id', 'vin', 'stock_no', 'seller_name','street']
df_cleaned.drop(columns=columns_to_drop, inplace=True)

# %%
df_cleaned.shape[0]
# Out:
# 1902606

# %%
df_filtered = df_cleaned[df_cleaned['year'] >= 2017]

# %%
# Filter the DataFrame to keep only rows where `miles` is less than or equal to 300000
df_filtered = df_filtered[df_filtered['miles'] <= 300000]

# %%
df_filtered = df_filtered[df_filtered['miles'] >= 500]

# %%
df_filtered = df_filtered[df_filtered['price'] >= 7000]

# %%
# List of all US states
us_states = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

# %%
# Filter out non-US states
df_filtered = df_filtered[df_filtered['state'].isin(us_states)]

# %%
makes_to_drop = make_counts[make_counts < 10489].index

# %%
df_filtered = df_filtered[~df_filtered['make'].isin(makes_to_drop)]

# %%
df_filtered = pd.concat([df_filtered, df_tesla_filtered], ignore_index=True)

# %%
df_sampled = df_filtered.sample(n=150000, random_state=42)

# %%
df_sampled.head(25)
# Out:
#            price  miles  year        make                model  \
# 881178   22987.0  32370  2020      Nissan               Altima
# 674970   23745.0  30704  2017      Subaru              Outback
# 253670   18369.0  22540  2018        Jeep              Compass
# 547848   36988.0  40639  2018         BMW                   X4
# 698468   36499.0  41436  2017       Lexus                   RX
# 460675   57843.0  15945  2020         GMC          Sierra 1500
# 938522   49500.0  17562  2020   Chevrolet       Silverado 1500
# 84650    16100.0  46800  2018        Ford                Focus
# 299857   21222.0  53393  2018      Nissan                Rogue
# 680773   46995.0   9664  2019        Ford                F-150
# 127913   49800.0  53122  2018         BMW             M4 Coupe
# 323571   36977.0  60650  2018        Ford                F-150
# 421838   31406.0   5978  2019         RAM  ProMaster Cargo Van
# 136174   41911.0  48215  2018      Toyota              4Runner
# 824747   37995.0  28655  2018        Ford                F-150
# 1023623  27000.0   3686  2020      Toyota                 RAV4
# 636297   19400.0  35576  2019        Jeep             Renegade
# 68893    59990.0  25883  2017  Land Rover   Range Rover Evoque
# 516091   41702.0  35973  2018   Chevrolet             Colorado
# 465138   39750.0  14707  2020   Chevrolet       Silverado 1500
# 10101    17429.0  60683  2020     Hyundai                 Kona
# 67977    24900.0  39476  2018     Hyundai        Sonata Hybrid
# 802721   14027.0  34644  2017       Honda                Civic
# 931876   47675.0  45878  2019         GMC             Yukon XL
# 798958   25988.0  22793  2017       Mazda        MX-5 Miata RF
#
#                    trim  body_type vehicle_type drivetrain transmission  \
# 881178               SL      Sedan          Car        FWD    Automatic
# 674970          Limited      Wagon          Car        4WD    Automatic
# 253670         Latitude        SUV        Truck        4WD    Automatic
# 547848        xDrive28i        SUV        Truck        4WD    Automatic
# 698468              350        SUV        Truck        4WD    Automatic
# 460675              AT4     Pickup        Truck        4WD    Automatic
# 938522              RST     Pickup        Truck        4WD    Automatic
# 84650                SE  Hatchback          Car        FWD    Automatic
# 299857               SV  Crossover        Truck        4WD    Automatic
# 680773              XLT     Pickup        Truck        4WD    Automatic
# 127913             Base      Coupe          Car        RWD    Automatic
# 323571              XLT     Pickup        Truck        4WD    Automatic
# 421838             Base  Cargo Van        Truck        FWD    Automatic
# 136174         Off-Road        SUV        Truck        4WD    Automatic
# 824747       King Ranch     Pickup        Truck        4WD    Automatic
# 1023623              LE        SUV        Truck        4WD    Automatic
# 636297         Latitude        SUV        Truck        FWD    Automatic
# 68893       HSE Dynamic        SUV        Truck        4WD    Automatic
# 516091              ZR2     Pickup        Truck        4WD    Automatic
# 465138       Work Truck     Pickup        Truck        4WD    Automatic
# 10101                SE        SUV        Truck        FWD    Automatic
# 67977    Hybrid Limited      Sedan          Car        FWD    Automatic
# 802721               LX      Sedan          Car        FWD    Automatic
# 931876              SLT        SUV        Truck        4WD    Automatic
# 798958    Grand Touring   Roadster          Car        RWD       Manual
#
#                                    fuel_type engine_size engine_block  \
# 881178                              Unleaded         2.5            I
# 674970                              Unleaded         2.5            H
# 253670                              Unleaded         2.4            I
# 547848                      Premium Unleaded         2.0            I
# 698468                              Unleaded         3.5            V
# 460675                              Unleaded         5.3            V
# 938522                              Unleaded         5.3            V
# 84650                               Unleaded         2.0            I
# 299857                              Unleaded         2.5            I
# 680773                              Unleaded         2.7            V
# 127913                      Premium Unleaded         3.0            I
# 323571                              Unleaded         2.7            V
# 421838                        E85 / Unleaded         3.6            V
# 136174                              Unleaded         4.0            V
# 824747   E85 / Unleaded; Unleaded / Unleaded         5.0            V
# 1023623                             Unleaded         2.5            I
# 636297                      Premium Unleaded         2.4            I
# 68893                               Unleaded         2.0            I
# 516091                                Diesel         2.8            I
# 465138                              Unleaded         5.3            V
# 10101                               Unleaded         2.0            I
# 67977                    Electric / Unleaded         2.0            I
# 802721                              Unleaded         2.0            I
# 931876                              Unleaded         5.3            V
# 798958                      Premium Unleaded         2.0            I
#
#                   city state      zip
# 881178         Hammond    LA  70403.0
# 674970           Exton    PA  19341.0
# 253670        Lakeland    FL    33810
# 547848      Round Rock    TX    78664
# 698468         Chicago    IL    60642
# 460675       Watertown    NY    13601
# 938522       Lafayette    IN  47905.0
# 84650           Tucson    AZ    85711
# 299857        Savannah    TN    38372
# 680773     San Antonio    TX    78216
# 127913     Bridgewater    NJ    08807
# 323571   Michigan City    IN    46360
# 421838        Hooksett    NH    03106
# 136174        Columbia    SC  29203.0
# 824747         Orlando    FL    32809
# 1023623     Portsmouth    NH    03801
# 636297        Glendale    CA    91204
# 68893         Sarasota    FL    34233
# 516091       Park City    UT    84098
# 465138      Harrisburg    PA    17112
# 10101          Merriam    KS    66202
# 67977           Dothan    AL    36301
# 802721      West Islip    NY    11795
# 931876          Tustin    CA    92782
# 798958          Duluth    GA    30096

# %%
df_sampled.to_csv('used_clean.csv', index=False)
