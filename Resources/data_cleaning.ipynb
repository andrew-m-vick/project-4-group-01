# %%
import pandas as pd

# %%
df = pd.read_csv('us-dealers-used.csv')
# Out:
# /var/folders/7b/trlfgd_d5gv_jv53bccbf7rw0000gn/T/ipykernel_57823/4071429681.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('us-dealers-used.csv')

# %%
df.head()
# Out:
#               id                vin    price     miles    stock_no    year  \
# 0  38b2f52e-8f5d  1GCWGFCF3F1284719  20998.0  115879.0  W1T503168C  2015.0
# 1  97ba4955-ccf0  WBY7Z8C59JVB87514  27921.0    7339.0      P33243  2018.0
# 2  be1da9fd-0f34  ML32F4FJ2JHF10325  11055.0   39798.0     WM2091A  2018.0
# 3  84327e45-6cb6  1GCPTEE15K1291189  52997.0   28568.0    9U2Y425A  2019.0
# 4  cde691c3-91dd  1G2AL18F087312093      NaN  188485.0     T36625A  2008.0
#
#          make          model      trim  body_type  ... drivetrain  \
# 0   Chevrolet  Express Cargo  Work Van  Cargo Van  ...        RWD
# 1         BMW             i3         s  Hatchback  ...        RWD
# 2  Mitsubishi      Mirage G4        SE      Sedan  ...        FWD
# 3   Chevrolet       Colorado       ZR2     Pickup  ...        4WD
# 4     Pontiac             G5      Base      Coupe  ...        FWD
#
#   transmission                    fuel_type engine_size  engine_block  \
# 0    Automatic               E85 / Unleaded         4.8             V
# 1    Automatic  Electric / Premium Unleaded         0.6             I
# 2    Automatic                     Unleaded         1.2             I
# 3    Automatic                       Diesel         2.8             I
# 4    Automatic                     Unleaded         2.2             I
#
#                     seller_name                        street           city  \
# 0          nissan ellicott city  8569 Baltimore National Pike  Ellicott City
# 1  hendrick honda pompano beach        5381 N Federal Highway  Pompano Beach
# 2            russ darrow toyota      2700 West Washington St.      West Bend
# 3                     young kia         308 North Main Street         Layton
# 4                 pappas toyota              10011 Spencer Rd   Saint Peters
#
#   state    zip
# 0    MD  21043
# 1    FL  33064
# 2    WI  53095
# 3    UT  84041
# 4    MO  63376
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7104304 entries, 0 to 7104303
# Data columns (total 21 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   id            object
#  1   vin           object
#  2   price         float64
#  3   miles         float64
#  4   stock_no      object
#  5   year          float64
#  6   make          object
#  7   model         object
#  8   trim          object
#  9   body_type     object
#  10  vehicle_type  object
#  11  drivetrain    object
#  12  transmission  object
#  13  fuel_type     object
#  14  engine_size   float64
#  15  engine_block  object
#  16  seller_name   object
#  17  street        object
#  18  city          object
#  19  state         object
#  20  zip           object
# dtypes: float64(4), object(17)
# memory usage: 1.1+ GB

# %%
pd.set_option('display.max_rows', None)

make_counts = df['make'].value_counts()
make_counts
# Out:
# make
# Ford             933834
# Chevrolet        815351
# Toyota           647263
# Honda            516484
# Nissan           451098
# Jeep             433401
# BMW              270940
# Hyundai          268377
# GMC              256735
# Mercedes-Benz    227486
# Kia              226792
# RAM              211684
# Dodge            205920
# Subaru           190266
# Lexus            179314
# Volkswagen       159730
# Audi             128078
# Mazda            111099
# Cadillac         102680
# Acura             99906
# Buick             92328
# INFINITI          83252
# Chrysler          79927
# Lincoln           66740
# Land Rover        63629
# Volvo             52264
# Porsche           40292
# MINI              37294
# Mitsubishi        32919
# Jaguar            26907
# Alfa Romeo        10488
# Maserati           9641
# GENESIS            8704
# Scion              8022
# Pontiac            8019
# FIAT               7184
# Tesla              7139
# Mercury            4637
# Saturn             4501
# Bentley            4193
# Ferrari            3781
# Hummer             2779
# Suzuki             1976
# Aston Martin       1796
# Rolls-Royce        1645
# smart              1427
# Lamborghini        1423
# Isuzu              1201
# McLaren            1196
# Saab                946
# Oldsmobile          642
# Plymouth            244
# KARMA               160
# Lotus               142
# Am General          121
# Eagle               118
# Geo                  55
# Fisker               52
# Maybach              23
# Bugatti              23
# Sterling             22
# Datsun                7
# Daewoo                3
# Peugeot               2
# Panoz                 1
# AMC                   1
# Name: count, dtype: int64

# %%
df_tesla = df[df['make'].str.lower() == 'tesla'].copy()

# %%
df_tesla['transmission'] = df_tesla['transmission'].fillna('Automatic')
df_tesla['fuel_type'] = df_tesla['fuel_type'].fillna('Electric')
df_tesla['engine_block'] = df_tesla['engine_block'].fillna('E')
df_tesla['engine_size'] = df_tesla['engine_size'].fillna('E')

# %%
df_tesla.dropna(inplace=True)

# %%
df.dropna(inplace=True)

# %%
# Convert `miles` and `year` columns to integer
df['miles'] = df['miles'].astype(int)
df['year'] = df['year'].astype(int)

# %%
# Drop specified columns
columns_to_drop = ['id', 'vin', 'stock_no', 'seller_name','street']
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.shape[0]
# Out:
# 6167605

# %%
df_filtered = df[df['year'] >= 2017]

# %%
# Filter the DataFrame to keep only rows where `miles` is less than or equal to 300000
df_filtered = df[df['miles'] <= 300000]

# %%
makes_to_drop = make_counts[make_counts < 10489].index

# %%
# List of all US states
us_states = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

# %%
# Filter out non-US states
df_filtered = df_filtered[df_filtered['state'].isin(us_states)]

# %%
df_filtered = df_filtered[~df_filtered['make'].isin(makes_to_drop)]

# %%
df_filtered = pd.concat([df_filtered, df_tesla], ignore_index=True)

# %%
df_sampled = df_filtered.sample(n=150000, random_state=42)

# %%
df_sampled.head(25)
# Out:
#            price     miles    year        make                       model  \
# 5775958  24987.0  101328.0  2017.0        Jeep  All-New Wrangler Unlimited
# 5650569  13694.0  107999.0  2013.0        Ford                        Edge
# 5094670  20829.0   29745.0  2018.0        Ford                      Escape
# 4934478  16595.0   65770.0  2014.0         BMW                          X1
# 1793254  19643.0   22036.0  2018.0  Volkswagen                      Tiguan
# 2386763  21988.0    5628.0  2020.0      Toyota                       Camry
# 1270784  28896.0   26604.0  2019.0   Chevrolet                    Traverse
# 3461751  25987.0    8849.0  2019.0        Ford                       F-150
# 1539656  94469.0    9970.0  2020.0         BMW                          M5
# 665948   25949.0   18696.0  2019.0       Acura                         TLX
# 5195458  14000.0   37924.0  2018.0      Nissan                      Sentra
# 10446    21888.0   17079.0  2004.0        Ford                 Thunderbird
# 76146     9889.0   90707.0  2014.0       Buick                       Regal
# 5395589  34300.0     651.0  2021.0      Toyota                        RAV4
# 5453259  17235.0   38138.0  2018.0      Nissan                       Rogue
# 3645916  18950.0   44085.0  2017.0      Toyota                       Prius
# 2933853  37899.0   40174.0  2018.0   Chevrolet              Silverado 1500
# 4046858  21484.0   68640.0  2015.0       Acura                         TLX
# 839177   13460.0  132952.0  2014.0      Toyota                        RAV4
# 4313077  27625.0   37990.0  2019.0       Dodge                     Charger
# 5448399  21868.0   14182.0  2020.0      Nissan                       Rogue
# 961147   26838.0   55308.0  2017.0        Jeep                    Cherokee
# 6041438  38919.0   11049.0  2020.0         RAM             Ram 1500 Pickup
# 3513967  14997.0   40871.0  2017.0  Volkswagen                       Jetta
# 5310623  20988.0   31808.0  2018.0        Jeep                     Compass
#
#                        trim    body_type vehicle_type drivetrain transmission  \
# 5775958               Sport          SUV        Truck        4WD       Manual
# 5650569             Limited    Crossover        Truck        FWD    Automatic
# 5094670                  SE          SUV        Truck        4WD    Automatic
# 4934478                 35i          SUV          Car        4WD    Automatic
# 1793254                   S          SUV        Truck        4WD    Automatic
# 2386763                  LE        Sedan          Car        FWD    Automatic
# 1270784                 1LT          SUV        Truck        FWD    Automatic
# 3461751                 XLT       Pickup        Truck        RWD    Automatic
# 1539656                Base        Sedan          Car        4WD    Automatic
# 665948                 Base        Sedan          Car        FWD    Automatic
# 5195458                  SV        Sedan          Car        FWD    Automatic
# 10446                Deluxe  Convertible          Car        RWD    Automatic
# 76146                  Base        Sedan          Car        FWD    Automatic
# 5395589             Limited          SUV        Truck        4WD    Automatic
# 5453259                   S    Crossover        Truck        4WD    Automatic
# 3645916                 Two    Hatchback          Car        FWD    Automatic
# 2933853                  LT       Pickup        Truck        4WD    Automatic
# 4046858  Technology Package        Sedan          Car        FWD    Automatic
# 839177                   LE          SUV        Truck        FWD    Automatic
# 4313077                 SXT        Sedan          Car        RWD    Automatic
# 5448399                  SV    Crossover        Truck        FWD    Automatic
# 961147             Overland          SUV        Truck        FWD    Automatic
# 6041438  Big Horn/Lone Star       Pickup        Truck        RWD    Automatic
# 3513967                   S        Sedan          Car        FWD       Manual
# 5310623            Latitude          SUV        Truck        4WD       Manual
#
#          ... engine_size engine_block           city state      zip   id  vin  \
# 5775958  ...         3.6            V     Carrollton    GA    30117  NaN  NaN
# 5650569  ...         3.5            V    Orange City    FL    32763  NaN  NaN
# 5094670  ...         1.5            I   Orchard Park    NY    14127  NaN  NaN
# 4934478  ...         3.0            I    Carson City    NV    89701  NaN  NaN
# 1793254  ...         2.0            I      Merrimack    NH    03054  NaN  NaN
# 2386763  ...         2.5            I   Owings Mills    MD    21117  NaN  NaN
# 1270784  ...         3.6            V        Lansing    MI    48912  NaN  NaN
# 3461751  ...         5.0            V      Johnsbury    VT    05819  NaN  NaN
# 1539656  ...         4.4            V     Louisville    KY    40216  NaN  NaN
# 665948   ...         2.4            I           Cary    NC    27511  NaN  NaN
# 5195458  ...         1.8            I       Florence    KY    41042  NaN  NaN
# 10446    ...         3.9            V  Fort Atkinson    WI    53538  NaN  NaN
# 76146    ...         2.0            I     Doylestown    PA    18902  NaN  NaN
# 5395589  ...         2.5            I       Fallston    MD    21047  NaN  NaN
# 5453259  ...         2.5            I     Hackensack    NJ    07601  NaN  NaN
# 3645916  ...         1.8            I          Pearl    MS    39208  NaN  NaN
# 2933853  ...         5.3            V         Shelby    NC    28152  NaN  NaN
# 4046858  ...         3.5            V        Lincoln    NE    68521  NaN  NaN
# 839177   ...         2.5            I        Houston    TX    77054  NaN  NaN
# 4313077  ...         3.6            V       Columbia    SC    29210  NaN  NaN
# 5448399  ...         2.5            I        Cumming    GA    30040  NaN  NaN
# 961147   ...         3.2            V  Coconut Creek    FL    33073  NaN  NaN
# 6041438  ...         5.7            V         Winder    GA    30680  NaN  NaN
# 3513967  ...         1.4            I         Tilton    NH    03276  NaN  NaN
# 5310623  ...         2.4            I     Greensburg    PA  15601.0  NaN  NaN
#
#         stock_no seller_name street
# 5775958      NaN         NaN    NaN
# 5650569      NaN         NaN    NaN
# 5094670      NaN         NaN    NaN
# 4934478      NaN         NaN    NaN
# 1793254      NaN         NaN    NaN
# 2386763      NaN         NaN    NaN
# 1270784      NaN         NaN    NaN
# 3461751      NaN         NaN    NaN
# 1539656      NaN         NaN    NaN
# 665948       NaN         NaN    NaN
# 5195458      NaN         NaN    NaN
# 10446        NaN         NaN    NaN
# 76146        NaN         NaN    NaN
# 5395589      NaN         NaN    NaN
# 5453259      NaN         NaN    NaN
# 3645916      NaN         NaN    NaN
# 2933853      NaN         NaN    NaN
# 4046858      NaN         NaN    NaN
# 839177       NaN         NaN    NaN
# 4313077      NaN         NaN    NaN
# 5448399      NaN         NaN    NaN
# 961147       NaN         NaN    NaN
# 6041438      NaN         NaN    NaN
# 3513967      NaN         NaN    NaN
# 5310623      NaN         NaN    NaN
#
# [25 rows x 21 columns]

# %%
df_sampled.to_csv('used_clean.csv', index=False)
